# %% [markdown]
# #Dense Model - Multi-class Dataset
# # Deep Learning Medical Image Analysis
# A dense neural network model trained using a simple pathology image dataset.

# %% [markdown]
# ## Python Imports
# This section will load the necessary python packages to the instance.

# %%
from tensorflow import keras
keras.__version__
# Out:
# '2.12.0'

# %%
# Built-in Imports
import random

# %%
# Library Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# Keras Imports
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import get_file, to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, Flatten, Dropout

# %% [markdown]
# ## Dataset Downloader (BloodMNIST)
# This section will download the selected [MedMNIST](https://medmnist.github.io/) dataset as a NumPy array object to your Google Colab instance.
#
# ### Here we are using the BloodMNIST dataset

# %%
DATA_NAME = "BloodMNIST"

# %%
# !wget https://raw.githubusercontent.com/MedMNIST/MedMNIST/main/medmnist/info.py
from info import INFO
data = INFO[DATA_NAME.lower()]
# Out:
# --2023-04-11 12:17:53--  https://raw.githubusercontent.com/MedMNIST/MedMNIST/main/medmnist/info.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22841 (22K) [text/plain]
# Saving to: ‘info.py’
#
# info.py             100%[===================>]  22.31K  --.-KB/s    in 0s
#
# 2023-04-11 12:17:54 (94.8 MB/s) - ‘info.py’ saved [22841/22841]

# %%
# Downloads the dataset file hosted on Zenodo.
file_path = get_file(fname="dataset.npz",
                     origin=data["url"],
                     md5_hash=data["MD5"])
# Out:
# Downloading data from https://zenodo.org/record/6496656/files/bloodmnist.npz?download=1
# 35461855/35461855 [==============================] - 20s 1us/step

# %% [markdown]
# Here we normalize the input data images by dividing them by 255 becasue this is the maximum value a pixel can have depending on its lightness or darkness. This is done to achieve numerical stability. As the data range gets modified to [0,1], the weights are updated more efficiently and convergence happens faster. Also, the effect of irrelevant features gets reduced and the problem of vanishing gradient can be mitigated to a certain extent.

# %%
# Loads the downloaded NumPy object.
dataset = np.load(file_path)

# Gets the training images and labels from the NumPy object.
train_x = dataset["train_images"].astype('float32') / 255.0
train_y = dataset["train_labels"].astype('float32') / 255.0

# Gets the validation images and labels from the NumPy object.
val_x = dataset["val_images"].astype('float32') / 255.0
val_y = dataset["val_labels"].astype('float32') / 255.0

# Gets the testing images and labels from the NumPy object.
test_x = dataset["test_images"].astype('float32') / 255.0
test_y = dataset["test_labels"].astype('float32') / 255.0

# %% [markdown]
# Now we reshape the input data to match the expected shape by the network and also the dense neural network only accepts a 1D data.

# %%
train_x = train_x.reshape((train_x.shape[0], 28*28*3))
val_x = val_x.reshape((val_x.shape[0], 28*28*3))
test_x = test_x.reshape((test_x.shape[0], 28*28*3))

# %% [markdown]
# ## Data Exploration
# In this section we have a look at our data, their distributions to see if it is ready to be used within our machine learning algorithm.

# %%
# Declares a list of labels.
labels = list(data["label"].values()) + ["total"]
print(labels)
# Gets the counts for each label in each of our datasets.
_, train_counts = np.unique(train_y, return_counts=True)
_, val_counts = np.unique(val_y, return_counts=True)
_, test_counts = np.unique(test_y, return_counts=True)

# Prints the counts for each label from each dataset.
print(pd.DataFrame(list(zip(np.append(train_counts, [sum(train_counts)]),
                            np.append(val_counts, [sum(val_counts)]),
                            np.append(test_counts, [sum(test_counts)]))),
                   index=labels, columns=["Train", "Val", "Test"]))
# Out:
# ['basophil', 'eosinophil', 'erythroblast', 'immature granulocytes(myelocytes, metamyelocytes and promyelocytes)', 'lymphocyte', 'monocyte', 'neutrophil', 'platelet', 'total']
#                                                     Train   Val  Test
# basophil                                              852   122   244
# eosinophil                                           2181   312   624
# erythroblast                                         1085   155   311
# immature granulocytes(myelocytes, metamyelocyte...   2026   290   579
# lymphocyte                                            849   122   243
# monocyte                                              993   143   284
# neutrophil                                           2330   333   666
# platelet                                             1643   235   470
# total                                               11959  1712  3421

# %% [markdown]
# Now we convert the class labels to one-hot-encoded vectors which is necessary in multi-class classification problems.

# %%
#Calculating the number of class labels
classes_num = (len(list(data["label"].values())))

#Converting class labels to one-hot-encoded vectors
train_y = keras.utils.to_categorical(dataset["train_labels"], num_classes=classes_num)
val_y = keras.utils.to_categorical(dataset["val_labels"], num_classes=classes_num)
test_y = keras.utils.to_categorical(dataset["test_labels"], num_classes=classes_num)

# %% [markdown]
# ## Model Definition
# In this section we will define the neural network arcitecture. We are supposed to only include dense layers here. Therefore, to match the number of parameters with the original models, we take the input layer of **8** units and the hidden layer of **8** units as well. This will give us around **13k parameters** which is quite close to the original model having about 19k parameters. The input and the hidden layer have **relu** as their activation function. The output layer is a **softmax** activation function as it outputs the probability of each data point to belong to one of the class labels.
#
# We are using **categorical crossentropy** as our loss function as this is ideal function for multi-class classification problems.
#
# We will keep **SGD** as our optimizer in all our models so that we can compare all the models.

# %%
# Define the model architecture
model = keras.Sequential()
model.add(keras.layers.Dense(8, activation='relu', input_shape=(28*28*3,)))
model.add(keras.layers.Dense(8, activation='relu'))
model.add(keras.layers.Dense(8, activation='softmax'))

# Defines the parameters used during training.
BATCH_SIZE = 64
NUM_EPOCHS = 10
LEARNING_RATE = 0.001

# Defines the optimiser used to adjust the model weights and compiles the model.
optimiser = SGD(learning_rate=LEARNING_RATE)

# Compile the model
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['accuracy', 'AUC', 'Precision', 'Recall'])

# %%
# Build the model
model.build(input_shape=(None, 2352))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 18824
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dense_2 (Dense)             (None, 8)                 72
#
# =================================================================
# Total params: 18,968
# Trainable params: 18,968
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model Training
# This is where we define the training options and then train the model.

# %%
# We use the data generator to pass the training and validation data to the model to train it.
history = model.fit(train_x,
                    train_y,
                    epochs=NUM_EPOCHS,
                    batch_size=BATCH_SIZE,
                    validation_data=(val_x, val_y)
                    )
# Out:
# Epoch 1/10
# 187/187 [==============================] - 7s 7ms/step - loss: 2.0638 - accuracy: 0.1947 - auc: 0.5649 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.0478 - val_accuracy: 0.1863 - val_auc: 0.6204 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/10
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0385 - accuracy: 0.1952 - auc: 0.6217 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.0278 - val_accuracy: 0.1933 - val_auc: 0.6379 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/10
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0207 - accuracy: 0.1967 - auc: 0.6398 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.0109 - val_accuracy: 0.1963 - val_auc: 0.6539 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/10
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0044 - accuracy: 0.1958 - auc: 0.6495 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9947 - val_accuracy: 0.1951 - val_auc: 0.6553 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/10
# 187/187 [==============================] - 1s 5ms/step - loss: 1.9888 - accuracy: 0.1967 - auc: 0.6559 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9788 - val_accuracy: 0.1945 - val_auc: 0.6614 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/10
# 187/187 [==============================] - 1s 6ms/step - loss: 1.9731 - accuracy: 0.1967 - auc: 0.6603 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9626 - val_accuracy: 0.1939 - val_auc: 0.6642 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/10
# 187/187 [==============================] - 1s 6ms/step - loss: 1.9568 - accuracy: 0.1968 - auc: 0.6644 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9457 - val_accuracy: 0.1933 - val_auc: 0.6677 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/10
# 187/187 [==============================] - 1s 5ms/step - loss: 1.9394 - accuracy: 0.2011 - auc: 0.6690 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9278 - val_accuracy: 0.2027 - val_auc: 0.6723 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/10
# 187/187 [==============================] - 1s 5ms/step - loss: 1.9213 - accuracy: 0.2836 - auc: 0.6739 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9088 - val_accuracy: 0.3107 - val_auc: 0.6776 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/10
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9012 - accuracy: 0.3221 - auc: 0.6821 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8889 - val_accuracy: 0.3271 - val_auc: 0.6889 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ## Plot Learning Curves
# This is where we visualise the training of the model.

# %%
# Plots the training and validation accuracy over the number of epochs.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
# Plots the training and validation loss over the number of epochs.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plots the training and validation AUC over the number of epochs.
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plots the training and validation precision over the number of epochs.
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plots the training and validation recall over the number of epochs.
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
test_loss, test_acc, test_auc, test_precision, test_recall = model.evaluate(test_x, test_y)
# Out:
# 107/107 [==============================] - 1s 5ms/step - loss: 1.8934 - accuracy: 0.3280 - auc: 0.6866 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
print("PneumoniaMNIST\n" + "Loss - " + str(test_loss) + "\n" + "Accuracy - " + str(test_acc) + "\n" + "AUC - " + str(test_auc) + "\n" + "Precision - " + str(test_precision) + "\n" + "Recall - " + str(test_recall))
# Out:
# PneumoniaMNIST
# Loss - 1.8933942317962646
# Accuracy - 0.3279742896556854
# AUC - 0.6865771412849426
# Precision - 0.0
# Recall - 0.0

# %% [markdown]
# #Convolution + Dense Model - Multi-class Dataset
# # Deep Learning Medical Image Analysis
# A dense neural network model trained using a simple pathology image dataset.

# %% [markdown]
# ## Python Imports
# This section will load the necessary python packages to the instance.

# %%
from tensorflow import keras
keras.__version__
# Out:
# '2.12.0'

# %%
# Built-in Imports
import random

# %%
# Library Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# Keras Imports
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import get_file, to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Dataset Downloader (BloodMNIST)
# This section will download the selected [MedMNIST](https://medmnist.github.io/) dataset as a NumPy array object to your Google Colab instance.
#
# ### Here we are using the BloodMNIST dataset

# %%
DATA_NAME = "BloodMNIST"

# %%
# !wget https://raw.githubusercontent.com/MedMNIST/MedMNIST/main/medmnist/info.py
from info import INFO
data = INFO[DATA_NAME.lower()]
# Out:
# --2023-04-11 11:21:10--  https://raw.githubusercontent.com/MedMNIST/MedMNIST/main/medmnist/info.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22841 (22K) [text/plain]
# Saving to: ‘info.py.1’
#
# info.py.1           100%[===================>]  22.31K  --.-KB/s    in 0.002s
#
# 2023-04-11 11:21:10 (14.4 MB/s) - ‘info.py.1’ saved [22841/22841]

# %%
# Downloads the dataset file hosted on Zenodo.
file_path = get_file(fname="dataset.npz",
                     origin=data["url"],
                     md5_hash=data["MD5"])

# %%
# Loads the downloaded NumPy object.
dataset = np.load(file_path)

# Gets the training images and labels from the NumPy object.
train_x = dataset["train_images"]
train_y = dataset["train_labels"]

# Gets the validation images and labels from the NumPy object.
val_x = dataset["val_images"]
val_y = dataset["val_labels"]

# Gets the testing images and labels from the NumPy object.
test_x = dataset["test_images"]
test_y = dataset["test_labels"]

# %% [markdown]
# ## Data Exploration
# In this section we have a look at our data, their distributions to see if it is ready to be used within our machine learning algorithm.

# %%
# Declares a list of labels.
labels = list(data["label"].values()) + ["total"]

# Gets the counts for each label in each of our datasets.
_, train_counts = np.unique(train_y, return_counts=True)
_, val_counts = np.unique(val_y, return_counts=True)
_, test_counts = np.unique(test_y, return_counts=True)

# Prints the counts for each label from each dataset.
print(pd.DataFrame(list(zip(np.append(train_counts, [sum(train_counts)]),
                            np.append(val_counts, [sum(val_counts)]),
                            np.append(test_counts, [sum(test_counts)]))),
                   index=labels, columns=["Train", "Val", "Test"]))
# Out:
#                                                     Train   Val  Test
# basophil                                              852   122   244
# eosinophil                                           2181   312   624
# erythroblast                                         1085   155   311
# immature granulocytes(myelocytes, metamyelocyte...   2026   290   579
# lymphocyte                                            849   122   243
# monocyte                                              993   143   284
# neutrophil                                           2330   333   666
# platelet                                             1643   235   470
# total                                               11959  1712  3421

# %%
# Displays a random image from training dataset.
index = random.randint(0, len(train_x))
print(f"{index}: {labels[train_y[index][0]]}")
plt.imshow(train_x[random.randint(0, len(train_x))])
# Out:
# 4422: immature granulocytes(myelocytes, metamyelocytes and promyelocytes)

# %% [markdown]
# ## Data Processing
# In this section we will create a data loader for algorithm that will dynamiclly load and augment the data when needed. Following are the data augmentations we are applying-:
# *   horizontal_flip - Randomly flip inputs horizontally.
# *   rotation_range - Degree range for random rotations.
# *   width_shift_range - Fraction of total width shift
# *   height_shift_range - Fraction of total height shift
# *   shear_range - Shear Intensity (Shear angle in counter-clockwise direction in degrees)
# *   zoom_range - Percentage of zoom-in and zoom-out
# *   fill_mode - Points outside the boundaries of the input are filled according to the given mode:
#
# These augmentations are applied keeping in mind to keep the augmented images similar to the original as the augmented images would have the same label class as the original images. Applying too much augmentation may change the images to a large extent and would not make sense with the label classess.

# %%
# Defines the data generator that will be used to augment the images as they are loaded.
data_generator = ImageDataGenerator(
    rotation_range=40,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.1,
      zoom_range=0.1,
      horizontal_flip=True,
      fill_mode='nearest')

# %%
# Here we fit the ImageDataGenerator to the dataset
data_generator.fit(np.append(train_x, val_x, 0))

# %%
# Displays a random image from training dataset after augmentation.
index = random.randint(0, len(train_x))
print(f"{index}: {labels[train_y[index][0]]}")
plt.imshow(train_x[random.randint(0, len(train_x))])
# Out:
# 6461: neutrophil

# %% [markdown]
# ## Model Definition
# In this section we will define the neural network arcitecture. We will create a network with a combination of convolution and dense layers. Two convolution layers with two max pooling layers are enough. This serves both to augment the capacity of the network, and to further reduce the size of the
# feature maps, so that they aren't overly large when we reach the **Flatten** layer. The depth of the feature maps is progressively increasing in the network (from 32 to 64) because it allows the network to learn more complex and abstract features. The early layers of the network learn simple features like edges and corners, while the later layers learn more complex features like shapes and textures. This makes it easier for the network to discriminate between different classes of objects.
#
# We than add a flattening layer to flatten the output received from convolution layers and max pooling as dense layers only recieve 1D arrays as their inputs.
#
# We are adding two dense layers to the network, one of which will be the hidden layer and the other one will be the output layer. This gives us a combination of convolution and dense layers so that our feature maps are reduced to essential features and we also have a certain depth of dense networks to enhance the training of the data.
#
# We will also add a dropout layer with rate=0.5 after the flattening operation which acts as a regularization method and helps to make the network more robust.
#
# The dense layers have **relu** as their activation function. The output layer is a **softmax** activation function as it outputs the probability of each data point to belong to one of the class labels.
#
# We are using **categorical crossentropy** as our loss function as this is ideal function for multi-class classification problems.
#
# We will keep **SGD** as our optimizer in all our models so that we can compare all the models.

# %%
# Define the input layer of the model with the size of an image.
input = layers.Input(shape=train_x[0].shape)

# Defines the first convolutional layer with max pooling.
conv_1 = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(input)
pool_1 = layers.MaxPool2D(pool_size=(2, 2))(conv_1)

# Defines the second convolutional layer with max pooling.
conv_2 = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(pool_1)
pool_2 = layers.MaxPool2D(pool_size=(2, 2))(conv_2)

# Flattens the outputs of the convolutoonal layers into a one dimensional array.
flatten = layers.Flatten()(pool_2)

#Dropout layer
dropout1 = layers.Dropout(0.5)(flatten)

# Defines the output layer of the model a number of output nodes equal to the number of classes.
dense1 = layers.Dense(32, activation='relu')(dropout1)

# Defines the output layer of the model a number of output nodes equal to the number of classes.
output = layers.Dense(units=len(np.unique(train_y)), activation="softmax")(dense1)

# Initilises the defined model and prints summary of the model.
model = Model(inputs=input, outputs=output, name="Model")
print(model.summary())
# Out:
# Model: "Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 3)]       0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        896
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dropout_1 (Dropout)         (None, 1600)              0
#
#  dense_2 (Dense)             (None, 32)                51232
#
#  dense_3 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 70,888
# Trainable params: 70,888
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Model Training
# This is where we define the training options and then train the model.

# %%
# Defines the parameters used during training.
BATCH_SIZE = 64
NUM_EPOCHS = 10
LEARNING_RATE = 0.001

# %%
# Defines the optimiser used to adjust the model weights and compiles the model.
optimiser = SGD(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimiser, loss="categorical_crossentropy", metrics=["accuracy", "AUC", "Precision", "Recall"])

# %% [markdown]
# # Model fit

# %%
# We use the data generator to pass the training and validation data to the model to train it.
history = model.fit(data_generator.flow(train_x, to_categorical(train_y), batch_size=BATCH_SIZE),
                    steps_per_epoch=len(train_x) / BATCH_SIZE,
                    validation_data=data_generator.flow(val_x, to_categorical(val_y), batch_size=BATCH_SIZE),
                    validation_steps=len(val_x) / BATCH_SIZE,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/10
# 186/186 [==============================] - 36s 185ms/step - loss: 2.9319 - accuracy: 0.2320 - auc: 0.6392 - precision: 0.1898 - recall: 0.0115 - val_loss: 1.7092 - val_accuracy: 0.4054 - val_auc: 0.7907 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/10
# 186/186 [==============================] - 20s 107ms/step - loss: 1.7351 - accuracy: 0.3454 - auc: 0.7579 - precision: 0.6563 - recall: 0.0846 - val_loss: 1.5611 - val_accuracy: 0.4492 - val_auc: 0.8293 - val_precision: 0.9574 - val_recall: 0.0263
# Epoch 3/10
# 186/186 [==============================] - 19s 99ms/step - loss: 1.5817 - accuracy: 0.4056 - auc: 0.8063 - precision: 0.7077 - recall: 0.1520 - val_loss: 1.4203 - val_accuracy: 0.4848 - val_auc: 0.8571 - val_precision: 0.9327 - val_recall: 0.1618
# Epoch 4/10
# 186/186 [==============================] - 20s 108ms/step - loss: 1.4389 - accuracy: 0.4667 - auc: 0.8443 - precision: 0.7242 - recall: 0.2257 - val_loss: 1.3910 - val_accuracy: 0.4784 - val_auc: 0.8577 - val_precision: 0.8649 - val_recall: 0.1758
# Epoch 5/10
# 186/186 [==============================] - 20s 107ms/step - loss: 1.3208 - accuracy: 0.5208 - auc: 0.8713 - precision: 0.7236 - recall: 0.2953 - val_loss: 1.1329 - val_accuracy: 0.6192 - val_auc: 0.9153 - val_precision: 0.9315 - val_recall: 0.2780
# Epoch 6/10
# 186/186 [==============================] - 20s 107ms/step - loss: 1.2294 - accuracy: 0.5512 - auc: 0.8893 - precision: 0.7396 - recall: 0.3522 - val_loss: 0.9356 - val_accuracy: 0.7004 - val_auc: 0.9481 - val_precision: 0.9398 - val_recall: 0.4106
# Epoch 7/10
# 186/186 [==============================] - 19s 103ms/step - loss: 1.1301 - accuracy: 0.5866 - auc: 0.9075 - precision: 0.7507 - recall: 0.4057 - val_loss: 1.0552 - val_accuracy: 0.6489 - val_auc: 0.9235 - val_precision: 0.8536 - val_recall: 0.3779
# Epoch 8/10
# 186/186 [==============================] - 20s 107ms/step - loss: 1.0303 - accuracy: 0.6233 - auc: 0.9231 - precision: 0.7831 - recall: 0.4650 - val_loss: 0.7615 - val_accuracy: 0.7360 - val_auc: 0.9631 - val_precision: 0.9148 - val_recall: 0.5391
# Epoch 9/10
# 186/186 [==============================] - 19s 99ms/step - loss: 0.9503 - accuracy: 0.6574 - auc: 0.9348 - precision: 0.7885 - recall: 0.5106 - val_loss: 0.7439 - val_accuracy: 0.7231 - val_auc: 0.9610 - val_precision: 0.8203 - val_recall: 0.6133
# Epoch 10/10
# 186/186 [==============================] - 21s 112ms/step - loss: 0.9195 - accuracy: 0.6731 - auc: 0.9390 - precision: 0.7949 - recall: 0.5296 - val_loss: 0.6912 - val_accuracy: 0.7605 - val_auc: 0.9691 - val_precision: 0.9105 - val_recall: 0.5882

# %% [markdown]
# ## Plot Learning Curves (Model with Data Augmentation)
# This is where we visualise the training of the model.

# %%
# Plots the training and validation accuracy over the number of epochs.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
# Plots the training and validation loss over the number of epochs.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
test_loss, test_acc, test_auc, test_precision, test_recall = model.evaluate(data_generator.flow(test_x, to_categorical(test_y)))
# Out:
# 107/107 [==============================] - 3s 32ms/step - loss: 0.7213 - accuracy: 0.7527 - auc: 0.9651 - precision: 0.9015 - recall: 0.5753

# %% [markdown]
# As we can clearly see, the binary classification model is performing better without the augmenting the dataset. It's possible that the dataset already contains enough samples that are representative of the problem space, and additional data augmentation is adding noise instead of providing any additional value. Therefore, adding random noise or rotations to the images hasn't proved to be helpful.

# %% [markdown]
# We will compile the results of the model with data augmentation for final comparitive analysis. As we can see the validation loss is stagnating after certain number of epochs epochs, we will reduce the number of epochs to prevent overfitting.

# %%
final_model = Model(inputs=input, outputs=output, name="Model")
final_model.summary()
# Out:
# Model: "Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 3)]       0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        896
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dropout_1 (Dropout)         (None, 1600)              0
#
#  dense_2 (Dense)             (None, 32)                51232
#
#  dense_3 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 70,888
# Trainable params: 70,888
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Defines the parameters used during training.
BATCH_SIZE = 64
NUM_EPOCHS = 7
LEARNING_RATE = 0.001

# %%
# Defines the optimiser used to adjust the model weights and compiles the model.
optimiser = SGD(learning_rate=LEARNING_RATE)
final_model.compile(optimizer=optimiser, loss="categorical_crossentropy", metrics=["accuracy", "AUC", "Precision", "Recall"])

# %%
history = final_model.fit(data_generator.flow(train_x, to_categorical(train_y), batch_size=BATCH_SIZE),
                    steps_per_epoch=len(train_x) / BATCH_SIZE,
                    validation_data=data_generator.flow(val_x, to_categorical(val_y), batch_size=BATCH_SIZE),
                    validation_steps=len(val_x) / BATCH_SIZE,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/7
# 186/186 [==============================] - 21s 109ms/step - loss: 0.8586 - accuracy: 0.6877 - auc: 0.9468 - precision: 0.7973 - recall: 0.5541 - val_loss: 0.7467 - val_accuracy: 0.7103 - val_auc: 0.9600 - val_precision: 0.7864 - val_recall: 0.6215
# Epoch 2/7
# 186/186 [==============================] - 19s 99ms/step - loss: 0.8550 - accuracy: 0.6950 - auc: 0.9473 - precision: 0.8034 - recall: 0.5675 - val_loss: 0.6632 - val_accuracy: 0.7465 - val_auc: 0.9694 - val_precision: 0.8472 - val_recall: 0.6314
# Epoch 3/7
# 186/186 [==============================] - 21s 111ms/step - loss: 0.8035 - accuracy: 0.7057 - auc: 0.9533 - precision: 0.8040 - recall: 0.5941 - val_loss: 0.6399 - val_accuracy: 0.7769 - val_auc: 0.9717 - val_precision: 0.8949 - val_recall: 0.6414
# Epoch 4/7
# 186/186 [==============================] - 19s 100ms/step - loss: 0.7748 - accuracy: 0.7198 - auc: 0.9562 - precision: 0.8153 - recall: 0.6128 - val_loss: 0.5771 - val_accuracy: 0.8148 - val_auc: 0.9781 - val_precision: 0.8990 - val_recall: 0.6706
# Epoch 5/7
# 186/186 [==============================] - 20s 108ms/step - loss: 0.7630 - accuracy: 0.7257 - auc: 0.9576 - precision: 0.8157 - recall: 0.6172 - val_loss: 0.5428 - val_accuracy: 0.8125 - val_auc: 0.9800 - val_precision: 0.8816 - val_recall: 0.7173
# Epoch 6/7
# 186/186 [==============================] - 19s 100ms/step - loss: 0.7482 - accuracy: 0.7256 - auc: 0.9591 - precision: 0.8179 - recall: 0.6259 - val_loss: 0.5419 - val_accuracy: 0.8166 - val_auc: 0.9802 - val_precision: 0.8930 - val_recall: 0.6974
# Epoch 7/7
# 186/186 [==============================] - 20s 107ms/step - loss: 0.7037 - accuracy: 0.7435 - auc: 0.9638 - precision: 0.8282 - recall: 0.6502 - val_loss: 0.6336 - val_accuracy: 0.7722 - val_auc: 0.9717 - val_precision: 0.8593 - val_recall: 0.6671

# %%
# Plots the training and validation accuracy over the number of epochs.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
# Plots the training and validation loss over the number of epochs.
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plots the training and validation AUC over the number of epochs.
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plots the training and validation precision over the number of epochs.
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# Plots the training and validation recall over the number of epochs.
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
test_loss, test_acc, test_auc, test_precision, test_recall = final_model.evaluate(data_generator.flow(test_x, to_categorical(test_y)))
# Out:
# 107/107 [==============================] - 3s 27ms/step - loss: 0.6599 - accuracy: 0.7761 - auc: 0.9693 - precision: 0.8601 - recall: 0.6668

# %%
print("PneumoniaMNIST\n" + "Loss - " + str(test_loss) + "\n" + "Accuracy - " + str(test_acc) + "\n" + "AUC - " + str(test_auc) + "\n" + "Precision - " + str(test_precision) + "\n" + "Recall - " + str(test_recall))
# Out:
# PneumoniaMNIST
# Loss - 0.6599128842353821
# Accuracy - 0.7760888338088989
# AUC - 0.9693163633346558
# Precision - 0.860105574131012
# Recall - 0.6667640805244446
